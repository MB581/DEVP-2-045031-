# %% [markdown]
# # RED WINE QUALITY REPORT

# %% [markdown]
# ### OVERVIEW OF THE DATA

# %% [markdown]
# The dataset presents an intricate mosaic of information, covering factors such as acidity levels, alcohol content, volatile acidity, and various other crucial features. Central to the dataset is the "quality" variable, furnishing a numeric rating spanning from 1 to 10. This rating system illuminates the multifaceted elements that play a collective role in assessing the quality of red wine.

# %%
import streamlit as st
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# Load the data
data = pd.read_excel('red wine.xlsx')

# Set the page title (call this only once)
st.set_page_config(page_title='Red Wine Dashboard', layout='wide')

# Title for the dashboard
st.title('Red Wine Quality Dashboard')

# Slicer for filtering data by quality
selected_quality = st.selectbox('Select Wine Quality:', sorted(data['quality'].unique()))

# Filter data based on selected quality
filtered_data = data[data['quality'] == selected_quality]

# Display filtered data
st.write(f'## Filtered Data for Quality {selected_quality}')
st.dataframe(filtered_data)

# Dataset Preview
st.write('## Dataset Preview')
st.dataframe(data.head())

# Summary statistics
st.write('## Summary Statistics')
st.write(data.describe())

# Slicer for the correlation heatmap
selected_feature_corr = st.selectbox('Select Feature for Correlation Heatmap:', data.columns)
corr_selected_feature = data[[selected_feature_corr, 'quality']].corr()

# Correlation heatmap
st.write(f'## Correlation Heatmap for {selected_feature_corr} vs. Quality')
fig, ax = plt.subplots(figsize=(10, 8))
sns.heatmap(corr_selected_feature, annot=True, cmap='coolwarm', fmt=".2f", linewidths=.5, ax=ax)
st.pyplot(fig)

# Slicer for the wine quality distribution histogram
selected_feature_hist = st.selectbox('Select Feature for Wine Quality Distribution:', data.columns)

# Histogram of wine quality
st.write(f'## Distribution of Wine Quality based on {selected_feature_hist}')
fig, ax = plt.subplots(figsize=(8, 6))
sns.histplot(data[selected_feature_hist], bins=6, kde=True, color='skyblue', ax=ax)
st.pyplot(fig)

# Slicer for the scatter plot of alcohol content vs. quality
selected_feature_scatter_x = st.selectbox('Select Feature for X-axis in Scatter Plot:', data.columns)
selected_feature_scatter_y = st.selectbox('Select Feature for Y-axis in Scatter Plot:', data.columns)

# Scatter plot of selected features
st.write(f'## Scatter Plot: {selected_feature_scatter_x} vs. {selected_feature_scatter_y}')
fig, ax = plt.subplots(figsize=(10, 8))
sns.scatterplot(x=selected_feature_scatter_x, y=selected_feature_scatter_y, data=data, hue='quality', palette='viridis', ax=ax)
st.pyplot(fig)
# Out:
# 2024-01-16 12:49:51.558
# ...
#   command:
#
#     streamlit run C:\Users\mehak_rx4kigm\anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator()

# %% [markdown]
# ### ANALYSIS AND INTERPRETATION

# %% [markdown]
# 1. Filtered Data for Chosen Quality:
#
# Objective: Delve into the characteristics of wines with a specific quality rating.
#
# Analysis: By selecting a particular quality rating from the dropdown, users gain access to a filtered dataset, allowing for a granular exploration of the distinctive characteristics associated with wines of that specific quality tier. Detailed observations may reveal patterns in specific features contributing to higher or lower quality wines.
#
# Managerial Insights: Managers can leverage this feature to pinpoint the unique attributes influencing higher quality ratings. For instance, a focus on specific chemical compositions or growing conditions might guide decisions related to production processes and marketing strategies.
#
# 2. Dataset Preview:
#
# Objective: Offer a snapshot of the entire dataset.
#
# Analysis: The dataset preview section provides a concise but informative look into the initial rows of the dataset. This glimpse aids users in understanding the overall structural layout of the dataset, facilitating a quick orientation to the breadth of available features.
#
# Managerial Insights: This overview empowers managers to make informed decisions about which features to prioritize for in-depth analysis. It also assists in resource allocation and planning, ensuring that attention is directed to the most relevant aspects of the dataset.
#
# 3. Summary Statistics:
#
# Objective: Provide statistical insights into the dataset.
#
# Analysis: The summary statistics section offers a plethora of essential metrics for numerical features. Mean values, standard deviations, and distributional characteristics provide a comprehensive understanding of the dataset's central tendencies.
#
# Managerial Insights: Managers can leverage this detailed statistical information to gain comprehensive insights into the dataset. Understanding the range and distribution of features is crucial for making informed decisions about production processes, quality control, and potential areas of improvement.
#
# 4. Correlation Heatmap:
#
# Objective: Explore correlations between a selected feature and wine quality.
#
# Analysis: The heatmap visualization unveils the strength and nature of correlations between various features and wine quality. This provides a holistic view of how different attributes interplay in influencing the perceived quality of red wines.
#
# Managerial Insights: Managers can identify features that exhibit strong correlations with wine quality. This knowledge guides strategic decisions, allowing for a targeted focus on aspects that significantly impact wine quality, ultimately influencing production and quality enhancement initiatives.
#
# 5. Wine Quality Distribution Histogram:
#
# Objective: Examine the distribution of wine quality based on a chosen feature.
#
# Analysis: The histogram provides a visual representation of how wine quality is distributed across different values of a selected feature. This analysis aids in understanding how specific feature ranges are associated with different quality ratings.
#
# Managerial Insights: Managers can use this detailed insight into the distribution of wine quality to inform quality assurance protocols. Understanding the prevalence of certain features within specific quality tiers can guide decisions related to production optimization and targeted quality improvements.
#
# 6. Scatter Plot:
#
# Objective: Visualize the relationship between two selected features in a scatter plot.
#
# Analysis: The scatter plot visually represents the distribution of wines based on two selected features, with color indicating the wine quality. This visual analysis helps uncover potential patterns or trends in feature combinations associated with higher quality wines.
#
# Managerial Insights: Managers can gain valuable insights into feature combinations correlated with higher quality wines. This understanding is pivotal in making decisions related to ingredient proportions, refining production processes, and optimizing quality parameters.

# %% [markdown]
# ### CONCLUSION

# %% [markdown]
# The Red Wine Quality Dashboard serves as a sophisticated and indispensable instrument for extracting actionable insights from the dataset. It not only fosters a nuanced understanding of red wine characteristics but also guides informed decision-making in the realms of wine production and quality management. The detailed analyses provided by the dashboard empower managers to make strategic decisions that positively impact the quality and market positioning of red wines.

# %% [markdown]
# Source of the data: Kaggle
#
# Source of the codes: chatGPT
